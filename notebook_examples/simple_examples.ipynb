# %%
#@markdown Setup dependencies (Colab only)
# %%capture
try:
    import papyrus_scripts
except ImportError:
    # !pip uninstall papyrus-scripts -y
    # !pip install rdkit
    # !pip install --upgrade papyrus-scripts --no-cache-dir
    get_ipython().kernel.do_shutdown(True)
# Out:
# C:\Users\Olivier\.conda\envs\tmp_paps\Lib\site-packages\cupy\_environment.py:284: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   warnings.warn(

# %% [markdown]
# # 📖 Simple examples: using Papyrus-scripts

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/OlivierBeq/Papyrus-scripts/blob/master/notebook_examples/simple_examples.ipynb)

# %% [markdown]
# Welcome! This notebook is a hands-on reference for the everyday operations of `papyrus-scripts`: downloading the [Papyrus](https://doi.org/10.1186/s13321-022-00672-x) dataset, filtering it down to what you need, and retrieving matching protein targets and molecular descriptors.
#
# It first walks through the **🧩 object-oriented API** (`PapyrusDataset`) — the recommended way to work with the dataset since v2.0.0 — covering **every** `keep_*`/filtering method it offers. The **📚 legacy functional API**, which mirrors the same filters as standalone functions, is shown at the very end for backward compatibility.
#
# **Contents**
# 1. [🧩 The object-oriented API](#1)
#    - [📥 Loading a dataset](#1.1)
#    - [🔍 Filtering](#1.2)
#    - [🧬 Protein target data](#1.3)
#    - [🧪 Molecular descriptors](#1.4)
#    - [💾 Saving results](#1.5)
# 2. [📚 The legacy functional API](#2)

# %% [markdown]
# <a id="1"></a>
# ## 1. 🧩 The object-oriented API

# %% [markdown]
# <a id="1.1"></a>
# ### 📥 Loading a dataset

# %% [markdown]
# `PapyrusDataset` is the entry point of the object-oriented API. Constructing one does **not** download or read anything yet — it downloads and caches data lazily, exactly when a result is first needed.
#
# Its main construction parameters:
#
# | Parameter | Meaning |
# |---|---|
# | `version` | dataset release, e.g. `'2024.09.2'`, or `'latest'` |
# | `is3d` | use the stereochemistry-aware 3D dataset (default `False`, recommended for most ML use cases) |
# | `plusplus` | use Papyrus++, the curated high-confidence subset (default `True`) |
# | `chunksize` | read the data lazily in chunks rather than all at once (default `1_000_000`) |
# | `source_path` | custom download directory (default: [pystow](https://github.com/cthoyt/pystow)'s home folder) |
# | `download_progress` | show a progress bar while downloading (default `True`) |

# %%
from papyrus_scripts import PapyrusDataset

dataset = PapyrusDataset(version='2024.09.1', plusplus=True)
dataset
# Out:
# PapyrusDataset<is3d=False, version=2024.09.1, plusplus=True, chunksize=1000000, source_path=None, download_progress=True, keep_original_files=False, disk_margin=0.1>

# %% [markdown]
# <a id="1.2"></a>
# ### 🔍 Filtering

# %% [markdown]
# Every filtering method — every `keep_*`, `contains`/`not_contains`, and `isin`/`not_isin` — returns a **new** `PapyrusDataset` wrapping an updated lazy pipeline. Nothing is mutated in place, and nothing is downloaded, read, or evaluated until the chain is materialized with `.to_dataframe()` (or its aliases `.aggregate()`/`.agg()`/`.consume_chunks()`). This makes long filter chains cheap to build, reorder, and reuse.
#
# > 💡 **Tip:** every method below has an equivalent standalone function in the [legacy functional API](#2), listed in the last column.
#
# | Method | Keeps rows where... | Functional equivalent |
# |---|---|---|
# | `keep_quality(min_quality)` | data quality is at or above the given tier (`'low'`/`'medium'`/`'high'`) | `keep_quality` |
# | `keep_source(source)` | the bioactivity comes from the given source(s) (e.g. `'chembl'`) | `keep_source` |
# | `keep_activity_type(activity_types)` | the activity type matches (e.g. `'Ki'`, `'IC50'`) | `keep_type` |
# | `keep_accession(accession)` | the target matches the given UniProt accession(s) | `keep_accession` |
# | `keep_protein_class(classes)` | the target belongs to the given ChEMBL protein class(es) | `keep_protein_class` |
# | `keep_organism(organism)` | the target belongs to the given organism(s) | `keep_organism` |
# | `contains(column, value)` | *column* contains *value* | `keep_contains` |
# | `not_contains(column, value)` | *column* does **not** contain *value* | `keep_not_contains` |
# | `isin(column, values)` | *column* is one of *values* | `keep_match` |
# | `not_isin(column, values)` | *column* is **not** one of *values* | `keep_not_match` |
# | `keep_similar_molecules(smiles)` | the compound is similar to a query structure | `keep_similar` |
# | `keep_dissimilar_molecules(smiles)` | the compound is **not** similar to a query structure | `keep_dissimilar` |
# | `keep_substructure_molecules(smiles)` | the compound contains a query substructure | `keep_substructure` |
# | `keep_not_substructure_molecules(smiles)` | the compound does **not** contain a query substructure | `keep_not_substructure` |

# %% [markdown]
# #### Quality, source & activity type

# %%
high_quality = dataset.keep_quality('high')
chembl_sharma = dataset.keep_source(['chembl', 'sharma'])
binding_affinities = dataset.keep_activity_type(['Ki', 'KD'])

# Chained together
chained = (dataset
           .keep_quality('medium')
           .keep_source(['chembl', 'sharma'])
           .keep_activity_type(['Ki', 'KD']))
chained
# Out:
# PapyrusDataset<is3d=False, version=2024.09.1, plusplus=True, chunksize=1000000, source_path=None, download_progress=True, keep_original_files=False, disk_margin=0.1>

# %% [markdown]
# #### Protein-target filters: accession, protein class & organism

# %% [markdown]
# <u>Browsing <a href="https://www.ebi.ac.uk/chembl/visualise/">ChEMBL's protein target tree</a> is encouraged when picking classes.</u>

# %%
by_accession = dataset.keep_accession(['P31645', 'P31652'])  # human & rat serotonin transporter

by_class = dataset.keep_protein_class([{'l2': 'Ligand-gated ion channels'},
                                        {'l3': 'SLC superfamily of solute carriers'}])

by_organism = dataset.keep_organism(['Human', 'Rat'], generic_regex=True)

# %% [markdown]
# Putting it together: medium-and-above quality data for ligand-gated ion channels and SLC-superfamily transporters, restricted to K<sub>i</sub>/K<sub>D</sub> measurements on human and rat targets.

# %%
filtered = (dataset
            .keep_quality('medium')
            .keep_protein_class([{'l2': 'Ligand-gated ion channels'},
                                  {'l3': 'SLC superfamily of solute carriers'}])
            .keep_activity_type(['Ki', 'KD'])
            .keep_organism(['Human', 'Rat'], generic_regex=True))
filtered
# Out:
# PapyrusDataset<is3d=False, version=2024.09.1, plusplus=True, chunksize=1000000, source_path=None, download_progress=True, keep_original_files=False, disk_margin=0.1>

# %% [markdown]
# Nothing has been downloaded or read yet — call `.to_dataframe()` to materialize the chain.

# %%
df = filtered.to_dataframe()
print(f'Number of activity points: {df.shape[0]}')
df.head()
# Out:
# C:\Users\Olivier\Documents\GitHub\Papyrus-scripts2\src\papyrus_scripts\reader.py:85: FutureWarning: Papyrus '2024.09.1' is not the latest release (latest: '2024.09.2'). Consider upgrading to access the most recent data.
#   return process_data_version(version=version, root_folder=source_path)
# C:\Users\Olivier\Documents\GitHub\Papyrus-scripts2\src\papyrus_scripts\reader.py:85: FutureWarning: Papyrus '2024.09.1' is not the latest release (latest: '2024.09.2'). Consider upgrading to access the most recent data.
#   return process_data_version(version=version, root_folder=source_path)
# Number of activity points: 5892
# shape: (5, 34)
# ┌────────────┬─────────┬──────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Activity_I ┆ Quality ┆ source   ┆ CID        ┆ … ┆ pchembl_v ┆ pchembl_v ┆ Classific ┆ Organism  │
# │ D          ┆ ---     ┆ ---      ┆ ---        ┆   ┆ alue_Medi ┆ alue_MAD  ┆ ation     ┆ ---       │
# ...

# %% [markdown]
# #### Generic column filters: `contains`, `not_contains`, `isin`, `not_isin`

# %% [markdown]
# These four operate on **any** column, not just the ones with a dedicated `keep_*` method — handy for one-off or exploratory filtering.

# %%
generic_filtered = (dataset
                    .keep_accession('P00533')
                    .isin('target_id', ['P00533_L858R', 'P00533_L861Q'])   # only these mutants
                    .contains('InChIKey', 'UHFFFAOYSA')                    # a specific InChIKey skeleton class
                    .not_contains('InChIKey', '-O$', regex=True))          # exclude a InChIKey suffix pattern
generic_filtered.to_dataframe().head()
# Out:
# shape: (5, 32)
# ┌────────────┬─────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Activity_I ┆ Quality ┆ source    ┆ CID       ┆ … ┆ pchembl_v ┆ pchembl_v ┆ pchembl_v ┆ pchembl_v │
# │ D          ┆ ---     ┆ ---       ┆ ---       ┆   ┆ alue_SEM  ┆ alue_N    ┆ alue_Medi ┆ alue_MAD  │
# │ ---        ┆ str     ┆ str       ┆ str       ┆   ┆ ---       ┆ ---       ┆ an        ┆ ---       │
# │ str        ┆         ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ ---       ┆ f64       │
# │            ┆         ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆           │
# ╞════════════╪═════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ BCFGMOOMAD ┆ High    ┆ Christman ┆ Christman ┆ … ┆ 0.0       ┆ 2.0       ┆ 8.553     ┆ 0.0       │
# │ DAQU_on_P0 ┆         ┆ n2016     ┆ n2016.com ┆   ┆           ┆           ┆           ┆           │
# ...

# %% [markdown]
# #### Molecular similarity & substructure filters

# %% [markdown]
# These four require the `papyrus-scripts[subsim]` extra and the compound structures to be downloaded; they transparently build (once) and reuse an indexed search database behind the scenes — no manual setup required.
#
# > 📓 **Full coverage** (CPU vs. GPU search, the lower-level functional/`FPSubSim2` APIs, exact engine control) lives in [advanced_querying.ipynb](https://github.com/OlivierBeq/Papyrus-scripts/blob/master/notebook_examples/advanced_querying.ipynb). Here's the essence:

# %%
caffeine = 'Cn1cnc2c1c(=O)n(C)c(=O)n2C'

similar = dataset.keep_similar_molecules(caffeine, threshold=0.6).to_dataframe()
dissimilar = dataset.keep_dissimilar_molecules(caffeine, threshold=0.6).to_dataframe()
contains_benzene = dataset.keep_substructure_molecules('c1ccccc1').to_dataframe()
lacks_benzene = dataset.keep_not_substructure_molecules('c1ccccc1').to_dataframe()

# %% [markdown]
# <a id="1.3"></a>
# ### 🧬 Protein target data

# %% [markdown]
# `.proteins()` returns the protein target records matching the current filter chain, as a `PapyrusProteinSet` — materialize it the same way with `.to_dataframe()`.

# %%
protein_data = filtered.proteins().to_dataframe()
protein_data.head()

# %% [markdown]
# <a id="1.4"></a>
# ### 🧪 Molecular descriptors

# %% [markdown]
# Precomputed descriptors for the filtered compounds can be retrieved directly, without a separate download/read step, via `.molecular_descriptors(desc_type)`. Valid `desc_type` values: `'mold2'`, `'mordred'`, `'cddd'`, `'fingerprint'`, `'moe'`, or `'all'`.

# %%
descriptors = filtered.molecular_descriptors('mold2').to_dataframe()
descriptors.head()

# %% [markdown]
# <a id="1.5"></a>
# ### 💾 Saving results

# %% [markdown]
# Every materialized result is a regular [Polars](https://pola.rs/) `DataFrame` and can be saved like any other.

# %%
df.write_csv('filtered_activities.csv')
df.write_parquet('filtered_activities.parquet')  # smaller & faster to reload

# %% [markdown]
# > ⚠️ **Stereochemistry note:** for machine learning use cases, we recommend the dataset without stereochemistry (`is3d=False`, the default) — see the [README](https://github.com/OlivierBeq/Papyrus-scripts#-dataset-versions) for details on dataset versions and availability.

# %% [markdown]
# <a id="2"></a>
# ## 2. 📚 The legacy functional API

# %% [markdown]
# The functions below predate `PapyrusDataset` and are kept for backward compatibility — **new code should prefer the object-oriented API above.** Two practical differences:
# - data must be downloaded **explicitly** before it can be read (no automatic on-demand download);
# - filters are standalone functions taking `data` as their first argument, rather than chained methods.
#
# Otherwise, every filter mirrors its object-oriented counterpart 1-for-1 (see the [table above](#1.2)).

# %% [markdown]
# ### 📥 Downloading

# %%
from papyrus_scripts import download_papyrus

# Downloads the curated (Papyrus++) 2D data along with the mold2 and unirep descriptors
download_papyrus(version='latest', only_pp=True, structures=False, descriptors=['mold2', 'unirep'])

# %% [markdown]
# A custom directory to download the data to can be given via the `outdir` argument; it must then be passed as `source_path` to every reading function below.

# %% [markdown]
# ### 📄 Reading

# %% [markdown]
# `read_papyrus` reads the bioactivity data; `read_protein_set` reads the protein target table. Passing `chunksize` (any non-`None` value) returns a lazy chunked reader instead of loading everything into memory at once — useful on machines with limited RAM.

# %%
from papyrus_scripts import read_papyrus, read_protein_set

sample_data = read_papyrus(is3d=False, plusplus=True, chunksize=1_000_000, source_path=None)
protein_data = read_protein_set(version='latest', source_path=None)

# %% [markdown]
# ### 🔍 Filtering

# %% [markdown]
# All filtering functions live under `papyrus_scripts.preprocess` (and are re-exported at the top level) and start with `keep_`. They work identically whether `data` is a plain DataFrame or a chunked reader — the only difference is that chunked results must be materialized with `consume_chunks` once every filter has been applied.

# %%
from papyrus_scripts import (keep_quality, keep_source, keep_type, keep_accession,
                              keep_protein_class, keep_organism, consume_chunks)

filter1 = keep_quality(data=sample_data, min_quality='medium')
filter2 = keep_source(data=filter1, source=['chembl', 'sharma'])
filter3 = keep_protein_class(data=filter2, protein_data=protein_data,
                              classes=[{'l2': 'Ligand-gated ion channels'},
                                       {'l3': 'SLC superfamily of solute carriers'}])
filter4 = keep_type(data=filter3, activity_types=['Ki', 'KD'])
filter5 = keep_organism(data=filter4, protein_data=protein_data,
                         organism=['Human', 'Rat'], generic_regex=True)

filtered_data = consume_chunks(filter5, progress=True)
print(f'Number of activity points: {filtered_data.shape[0]}')

# %% [markdown]
# The four generic column filters (`keep_match`, `keep_not_match`, `keep_contains`, `keep_not_contains`) mirror `isin`/`not_isin`/`contains`/`not_contains` from the object-oriented API and take a plain `data`/`column`/`value(s)` signature:

# %%
from papyrus_scripts import keep_match, keep_not_match, keep_contains, keep_not_contains

step1 = keep_match(sample_data, column='target_id', values=['P00533_L858R', 'P00533_L861Q'])
step2 = keep_contains(step1, column='InChIKey', value='UHFFFAOYSA')
step3 = keep_not_contains(step2, column='InChIKey', value='-O$', regex=True)

# %% [markdown]
# Similarity, dissimilarity and substructure filters (`keep_similar`, `keep_dissimilar`, `keep_substructure`, `keep_not_substructure`) are covered in depth, alongside QSAR/PCM/DNN modelling, in [advanced_querying.ipynb](https://github.com/OlivierBeq/Papyrus-scripts/blob/master/notebook_examples/advanced_querying.ipynb) 🚀.
